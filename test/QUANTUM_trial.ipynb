# %%
import grequests
import requests
import numpy as np
import pandas as pd
import time
import json
import csv
from lxml import etree
# Out:
# c:\Users\benja\anaconda3\envs\python-env\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %%
reqs = [
    grequests.get('http://httpbin.org/delay/1', timeout=0.001),
    grequests.get('http://fakedomain/'),
    grequests.get('http://httpbin.org/status/500'),
    None
]
for index, response in grequests.imap_enumerated(reqs, size=5):
    print(index, response)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 7
#       1 reqs = [
#       2     grequests.get('http://httpbin.org/delay/1', timeout=0.001),
#       3     grequests.get('http://fakedomain/'),
#       4     grequests.get('http://httpbin.org/status/500'),
#       5     None
#       6 ]
# ----> 7 for index, response in grequests.imap_enumerated(reqs, size=5):
#       8     print(index, response)
#
# File c:\Users\benja\anaconda3\envs\python-env\Lib\site-packages\grequests.py:204, in imap_enumerated(requests, stream, size, exception_handler)
#     202 requests = list(requests)
#     203 for index, req in enumerate(requests):
# --> 204     req._index = index
#     206 for index, request in pool.imap_unordered(send, requests):
#     207     if request.response is not None:
#
# AttributeError: 'NoneType' object has no attribute '_index'
# c:\Users\benja\anaconda3\envs\python-env\Lib\site-packages\gevent\hub.py:161: UserWarning: libuv only supports millisecond timer resolution; all times less will be set to 1 ms
#   with loop.timer(seconds, ref=ref) as t:

# %% [markdown]
# Get dwsid

# %%
# THIS ONE FIRST, Get dwsid

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/121.0.0.0 Safari/537.36',
}

response_dwsid = requests.get('https://www.quantumfiber.com/', headers=headers)

# %%
dwsid = response_dwsid.cookies.get_dict()['dwsid']
# print(response_dwsid.cookies.get_dict().keys())
print(dwsid)
# Out:
# HOn03AlWkqVV4UK43uzIiOF24AU2i0wU-z4Uea9yMaLI0KadFMygrHcLlDp_v6xo4qrKYfUDYfQ3VUY1hLJJGA==

# %% [markdown]
# Try and get CRSF token tied to this dwsid

# %%
# this gets crsf tied with dwsid
cookies = {
    'dwsid': dwsid
}

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

response = requests.get('https://www.quantumfiber.com/shop/smartNidSpeeds', cookies=cookies, headers=headers)
print([resp.url for resp in response.history])
# qf-tile__price-amount
# cq_params.products
# Out:
# ['https://www.quantumfiber.com/shop/smartNidSpeeds']

# %%
# extract csrf
g = response.iter_content(decode_unicode=True)
line = []
for item in g:
    if item == '\n':
        line = ''.join(line)
        if ('csrf' in line):
            break
        line = []
    else:
        line.append(item)


tree = etree.HTML(line)
csrf = tree.find(".//input").get('value')
print(csrf)
# Out:
# lIS14u07mJxL4I2pQMHEmZHK0Is-ukvNs4qGV76p-ss_Lu4v9WDVb7nEqb_BbVVRzbAmdvn9ehHO5pRsD70sdxAcir_423zlmTI0w-SVSOqmbCwNPvdf298LDMMqQtOra8k3zMx5EcbMsl_1EKm0IGJHlpqTGLruhksocGD1NLBjw4QrJzg=

# %% [markdown]
# use crsf and dwsid to get address info?

# %%
cookies = {
    'dwsid': dwsid
}

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

data = {
    'dwfrm_addressChecker_o2check': '845 S  SULLIVAN ST SEATTLE WA 98108 USA',
    # 'o2_units': '',
    # 'dwfrm_addressChecker_unitNumber': '',
    'dwfrm_addressChecker_centurylinkExisting': 'false',
    # 'dwfrm_addressChecker_long': '',
    # 'dwfrm_addressChecker_lat': '',
    # 'dwfrm_addressChecker_streetnumber': '',
    # 'dwfrm_addressChecker_street': '',
    # 'dwfrm_addressChecker_city': '',
    # 'dwfrm_addressChecker_states_stateCode': '',
    # 'dwfrm_addressChecker_stateCodeLong': '',
    # 'dwfrm_addressChecker_zipcode': '',
    # 'dwfrm_addressChecker_predirection': '',
    # 'dwfrm_addressChecker_postdirection': '',
    # 'dwfrm_addressChecker_afstreetname': '',
    # 'dwfrm_addressChecker_afstreetsuffix': '',
    # 'dwfrm_addressChecker_countrycode': '',
    # 'dwfrm_addressChecker_addressGoogleFormatted': '',
    # 'dwfrm_addressChecker_isRooftop': '',
    # 'dwfrm_addressChecker_mdu': '',
    # 'dwfrm_addressChecker_addressId': '',
    # 'dwfrm_addressChecker_o2__units': '',
    # 'dwfrm_addressChecker_addressKey': '',
    'csrf_token': csrf,
    # 'null': 'null',
    # 'dwfrm_addressChecker_propertyId': '',
    # 'dwfrm_addressChecker_workType': '',
    # 'salescode': '',
    # 'o2unitsKeyedIn': '',
    # 'geo_type': '',
}

response = requests.post(
    'https://www.quantumfiber.com/on/demandware.store/Sites-QFCC-Site/default/AddressChecker-GetServiceability',
    cookies=cookies,
    headers=headers,
    data=data,
)

# %%
print(response.json()['action'])
# Out:
# AddressChecker-GetServiceability

# %% [markdown]
# Call the nid speeds again now that things are verified?

# %%
# this gets csrf without a dwsid?
cookies = {
    'dwsid': dwsid
}

headers = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

response = requests.get('https://www.quantumfiber.com/shop/smartNidSpeeds', cookies=cookies, headers=headers)
# qf-tile__price-amount
# cq_params.products

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang>
# <head>
# <script src="https://www.googleoptimize.com/optimize.js?id=OPT-NMRW4PS"></script>
# <!--[if gt IE 9]><!-->
# <script>//common/scripts.isml</script>
# <script defer type="text/javascript" src="/on/demandware.static/Sites-QFCC-Site/-/default/v1707242584047/js/main.js"></script>
# <script defer type="text/javascript" src="/on/demandware.static/Sites-QFCC-Site/-/default/v1707242584047/js/addressChecker.js">
#         </script>
# <!--<![endif]-->
# <meta charset="UTF-8">
# <meta http-equiv="x-ua-compatible" content="ie=edge">
# <meta name="viewport" content="width=device-width, initial-scale=1.0, maximum-scale=1.0, user-scalable=no" />
# <title>Check to See if Quantum Fiber is Available at Your Address!</title>
# <link rel="canonical" href="https://www.quantumfiber.com/shop/" />
# <meta name="description" content="Verify your address, to see if Quantum Fiber is available at your location." />
# <link rel="icon" type="image/png" href="/on/demandware.static/Sites-QFCC-Site/-/default/dwd0d69059/images/favicons/qf-favicon-196x196.png" sizes="196x196" />
# <link rel="icon" type="image/png" href="/on/demandware.static/Sites-QFCC-Site/-/default/dwa5f12103/images/favicons/qf-favicon-96x96.png" sizes="96x96" />
# <link rel="icon" type="image/png" href="/on/demandware.static/Sites-QFCC-Site/-/default/dwdf59c5a3/images/favicons/qf-favicon-32x32.png" sizes="32x32" />
# <link rel="icon" type="image/png" href="/on/demandware.static/Sites-QFCC-Site/-/default/dwb963fb91/images/favicons/qf-favicon-16x16.png" sizes="16x16" />
# <link rel="icon" type="image/png" href="/on/demandware.static/Sites-QFCC-Site/-/default/dw1577f2b5/images/favicons/qf-favicon-128x128.png" sizes="128x128" />
# <link rel="stylesheet" href="https://use.typekit.net/oyj0okb.css" />
# <link rel="stylesheet" href="https://use.typekit.net/lvm7clc.css" />
# <link rel="stylesheet" href="/on/demandware.static/Sites-QFCC-Site/-/default/v1707242584047/css/global.css" />
# <link rel="stylesheet" href="/on/demandware.static/Sites-QFCC-Site/-/default/v1707242584047/css/address-check.css" />
# <script>
# window.dataLayer = window.dataLayer || [];
# </script>
#
# <script>
# 	(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	                new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	                j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	                'https://www.googletagmanager.com/gtm.js?id='+i+dl+ '&gtm_auth=jWygDNlI5jMfkcMGVwTM1w&gtm_preview=env-1&gtm_cookies_win=x';f.parentNode.insertBefore(j,f);
# 	                })(window,document,'script','dataLayer','GTM-P4HKT96');
# </script>
#
#
# <script>
# 	(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# 	                new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# 	                j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 	                'https://www.googletagmanager.com/gtm.js?id='+i+dl+ '&gtm_auth=cIhYS6Uk9hcIPNf4pZSGiQ&gtm_cookies_win=x';f.parentNode.insertBefore(j,f);
# 	                })(window,document,'script','dataLayer','GTM-KJ5BFWX');
# </script>
#
#
# <script async src="https://www.googleoptimize.com/optimize.js?id=OPT-NMRW4PS"></script>
#
# <script>
# const encrypted_account_id = '';
# </script>
# <span id="pageInfo" data-page-info="null" data-page-title="Check to See if Quantum Fiber is Available at Your Address!" data-isoriginsbg="false">
# </span>
#
# <noscript>
# 	<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-KJ5BFWX&gtm_auth=cIhYS6Uk9hcIPNf4pZSGiQ&gtm_cookies_win=x" height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
#
#
# <noscript>
# 	<iframe src="https://www.googletagmanager.com/ns.html?id=GTM-P4HKT96&gtm_auth=jWygDNlI5jMfkcMGVwTM1w&gtm_preview=env-1&gtm_cookies_win=x" height="0" width="0" style="display:none;visibility:hidden"></iframe>
# </noscript>
#
# <script type="text/javascript">//<!--
# /* <![CDATA[ (head-active_data.js) */
# var dw = (window.dw || {});
# dw.ac = {
#     _analytics: null,
#     _events: [],
#     _category: "",
#     _searchData: "",
#     _anact: "",
#     _anact_nohit_tag: "",
#     _analytics_enabled: "true",
#     _timeZone: "US/Mountain",
#     _capture: function(configs) {
#         if (Object.prototype.toString.call(configs) === "[object Array]") {
#             configs.forEach(captureObject);
#             return;
#         }
#         dw.ac._events.push(configs);
#     },
# 	capture: function() {
# 		dw.ac._capture(arguments);
# 		// send to CQ as well:
# 		if (window.CQuotient) {
# 			window.CQuotient.trackEventsFromAC(arguments);
# 		}
# 	},
#     EV_PRD_SEARCHHIT: "searchhit",
#     EV_PRD_DETAIL: "detail",
#     EV_PRD_RECOMMENDATION: "recommendation",
#     EV_PRD_SETPRODUCT: "setproduct",
#     applyContext: function(context) {
#         if (typeof context === "object" && context.hasOwnProperty("category")) {
#         	dw.ac._category = context.category;
#         }
#         if (typeof context === "object" && context.hasOwnProperty("searchData")) {
#         	dw.ac._searchData = context.searchData;
#         }
#     },
#     setDWAnalytics: function(analytics) {
#         dw.ac._analytics = analytics;
#     },
#     eventsIsEmpty: function() {
#         return 0 == dw.ac._events.length;
#     }
# };
# /* ]]> */
# // -->
# </script>
# <script type="text/javascript">//<!--
# /* <![CDATA[ (head-cquotient.js) */
# var CQuotient = window.CQuotient = {};
# CQuotient.clientId = 'bgtm-QFCC';
# CQuotient.realm = 'BGTM';
# CQuotient.siteId = 'QFCC';
# CQuotient.instanceType = 'prd';
# CQuotient.locale = 'default';
# CQuotient.fbPixelId = '__UNKNOWN__';
# CQuotient.activities = [];
# CQuotient.cqcid='';
# CQuotient.cquid='';
# CQuotient.cqeid='';
# CQuotient.cqlid='';
# CQuotient.apiHost='api.cquotient.com';
# /* Turn this on to test against Staging Einstein */
# /* CQuotient.useTest= true; */
# CQuotient.useTest = ('true' === 'false');
# CQuotient.initFromCookies = function () {
# 	var ca = document.cookie.split(';');
# 	for(var i=0;i < ca.length;i++) {
# 	  var c = ca[i];
# 	  while (c.charAt(0)==' ') c = c.substring(1,c.length);
# 	  if (c.indexOf('cqcid=') == 0) {
# 		CQuotient.cqcid=c.substring('cqcid='.length,c.length);
# 	  } else if (c.indexOf('cquid=') == 0) {
# 		  var value = c.substring('cquid='.length,c.length);
# 		  if (value) {
# 		  	var split_value = value.split("|", 3);
# 		  	if (split_value.length > 0) {
# 			  CQuotient.cquid=split_value[0];
# 		  	}
# 		  	if (split_value.length > 1) {
# 			  CQuotient.cqeid=split_value[1];
# 		  	}
# 		  	if (split_value.length > 2) {
# 			  CQuotient.cqlid=split_value[2];
# 		  	}
# 		  }
# 	  }
# 	}
# }
# CQuotient.getCQCookieId = function () {
# 	if(window.CQuotient.cqcid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqcid;
# };
# CQuotient.getCQUserId = function () {
# 	if(window.CQuotient.cquid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cquid;
# };
# CQuotient.getCQHashedEmail = function () {
# 	if(window.CQuotient.cqeid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqeid;
# };
# CQuotient.getCQHashedLogin = function () {
# 	if(window.CQuotient.cqlid == '')
# 		window.CQuotient.initFromCookies();
# 	return window.CQuotient.cqlid;
# };
# CQuotient.trackEventsFromAC = function (/* Object or Array */ events) {
# try {
# 	if (Object.prototype.toString.call(events) === "[object Array]") {
# 		events.forEach(_trackASingleCQEvent);
# 	} else {
# 		CQuotient._trackASingleCQEvent(events);
# 	}
# } catch(err) {}
# };
# CQuotient._trackASingleCQEvent = function ( /* Object */ event) {
# 	if (event && event.id) {
# 		if (event.type === dw.ac.EV_PRD_DETAIL) {
# 			CQuotient.trackViewProduct( {id:'', alt_id: event.id, type: 'raw_sku'} );
# 		} // not handling the other dw.ac.* events currently
# 	}
# };
# CQuotient.trackViewProduct = function(/* Object */ cqParamData){
# 	var cq_params = {};
# 	cq_params.cookieId = CQuotient.getCQCookieId();
# 	cq_params.userId = CQuotient.getCQUserId();
# 	cq_params.emailId = CQuotient.getCQHashedEmail();
# 	cq_params.loginId = CQuotient.getCQHashedLogin();
# 	cq_params.product = cqParamData.product;
# 	cq_params.realm = cqParamData.realm;
# 	cq_params.siteId = cqParamData.siteId;
# 	cq_params.instanceType = cqParamData.instanceType;
# 	cq_params.locale = CQuotient.locale;
#
# 	if(CQuotient.sendActivity) {
# 		CQuotient.sendActivity(CQuotient.clientId, 'viewProduct', cq_params);
# 	} else {
# 		CQuotient.activities.push({activityType: 'viewProduct', parameters: cq_params});
# 	}
# };
# /* ]]> */
# // -->
# </script>
# </head>
# <body>
# <div class="page" data-action="AddressChecker-Show" data-querystring>
# <div role="main" id="maincontent">
# <div class="qf-modal modal fade" id="qfModalAttention" tabindex="-1" role="dialog" aria-hidden="true">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="qf-modal__error modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Attention
# </h5>
# <button type="button" class="close js-btnn-close" data-dismiss="modal" aria-label="Close">
# <span aria-hidden="true">
# <div class="icon icon__close " title="Close">
# <svg viewbox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.1428 10L19.3493 3.79362C20.2169 2.92572 20.2169 1.51882 19.3493 0.650922C18.4811 -0.216974 17.0744 -0.216974 16.2063 0.650922L9.99988 6.8573L3.7937 0.650922C2.92556 -0.216974 1.51864 -0.216974 0.650741 0.650922C-0.216914 1.51882 -0.216914 2.92572 0.650741 3.79362L6.85716 10L0.650741 16.2064C-0.216914 17.0743 -0.216914 18.4812 0.650741 19.3491C1.51889 20.217 2.92556 20.217 3.7937 19.3491L9.99988 13.1429L16.2063 19.3491C17.0742 20.217 18.4811 20.217 19.3493 19.3491C20.2169 18.4812 20.2169 17.0743 19.3493 16.2064L13.1428 10Z" fill="#788791" /></svg>
# </div>
# </span>
# </button>
# </div>
# <div class="modal-body">
# <div class="qf-modal__secondary-header"> </div> <div class="qf-modal__secondary-text"> <p>We are excited to transition your CenturyLink internet to Quantum Fiber internet. We know you'll love the lightning-fast and superior service. </p><p>Our records indicate that there may already be CenturyLink service at this address. If you are a new customer or are an existing customer who still needs assistance, please call us at 833-250-6306. You may also close this window to chat with a member from our Success Team. We're here to help!</p> </div>
# </div>
# </div>
# </div>
# </div>
# <script>
#         window._uxa = window._uxa || [];
#         window._uxa.push(['trackPageEvent', '@user-identifier@' + 'lsd28lmoatpdhs81j3a']);
#     </script>
# <div class="bf address-check">
# <div class="bf__header">
# <div class="bf-header">
# <div class="bf-header__wrapper">
# <div class="bf-header__logo">
# <a href="https://www.quantumfiber.com/">
# <div class="icon icon__logo " title>
,0,0,144,200Z" /><path class="cls-2" d="M117.53,0A117.52,117.52,0,0,0,0,117.53C0,179.62,46.3,213,77.63,213c23.11,0,41.08-9.24,48.92-22.89-27,0-76.15-25.8-76.16-72.57a67.12,67.12,0,1,1,134.24,0c0,32.62-16.44,62-40.61,82.41a177.21,177.21,0,0,1,39.87,27.46c30.7-28.08,51.19-66.95,51.19-109.87A117.55,117.55,0,0,0,117.53,0Z" /><path class="cls-2" d="M1017.79,227.42h44.94V136.13c0-22.35,11.2-31.63,26.07-31.63s26.07,11.53,26.07,26.83v96.09h44.93V136.13c0-22.35,11.21-31.63,26.07-31.63s26.07,11.53,26.07,26.83v96.09h44.93V131.33c0-44.65-25-72-64.8-72-18,0-36,7.45-47.37,22.07-11.26-14.19-28.34-22.07-49.71-22.07-17.46,0-37.32,7.74-46.89,19.75-6.23-12-17.73-16.73-27.92-16.73h-2.39Z" /><path class="cls-2" d="M1268.23,86.18a11.58,11.58,0,1,1,6-1.57A11.57,11.57,0,0,1,1268.23,86.18Zm0-2.64a8.86,8.86,0,0,0,4.59-1.18,8.67,8.67,0,0,0,3.19-3.28,9.89,9.89,0,0,0,0-9.37,8.73,8.73,0,0,0-3.19-3.25,9.48,9.48,0,0,0-9.16,0,8.63,8.63,0,0,0-3.21,3.25,9.82,9.82,0,0,0,0,9.37,8.57,8.57,0,0,0,3.21,3.28A8.92,8.92,0,0,0,1268.23,83.54Zm-4.13-3.85V68.58h3.8a5.71,5.71,0,0,1,3.52,1,3.22,3.22,0,0,1,1.26,2.72,3.4,3.4,0,0,1-1.92,3.36l2.53,4.07h-2.81l-2-3.52h-1.82v3.52Zm3.85-8.8h-1.32v3H1268c1.36,0,2-.51,2-1.54S1269.31,70.89,1268,70.89Z" /></g></svg>
# </div>
# </a>
# </div>
# <div class="bf-header__headline">
# <div class="html-slot-container">
# <span class="qf-headline">Great! Let’s get started</span>
# </div>
# </div>
# <div class="bf-header__cta"></div>
# </div>
# <div class="bf-header__instructional"></div>
# </div>
# </div>
# <form method="POST" action="/on/demandware.store/Sites-QFCC-Site/default/AddressChecker-GetServiceability" id="address-form" autocomplete="off">
# <div class="bf__main">
# <div class="qf-grid">
# <div class="qf-grid__container qf-grid__single">
# <div class="row">
# <div class="content-asset">
# <div class="col-12"> <span class="address-check__form-text">Check availability </span> </div> <div class="col-12"> <span class="address-check__form-instuct">Enter your address to check availability.</span> </div>
# </div>
# </div>
# <div class="row address-check__forms-wrapper o2-address-checker">
# <div id="js-serviceAddress-wrapper" class="form-group required col-12 col-sm-8" data-url="/on/demandware.store/Sites-QFCC-Site/default/AddressChecker-GetServiceability">
# <div class="form-control-animation">
# <input id="o2check" data-transfer="false" class="form-control" type="text" placeholder aria-describedby="o2-address-error" name="dwfrm_addressChecker_o2check" required aria-required="true" value maxLength="2147483647" />
# <label class="form-control-label" for="serviceAddress">
# My street address
# </label>
# </div>
# </div>
# <div class="form-group
#                                      col-12 col-sm-4">
# <div id="o2-unit-select-container">
# <label for="o2UnitsOptions" class="required-field mdu-label">
# Select or enter unit
# </label>
# <select id="o2UnitsOptions" class="o2-align-checker" name="o2_units">
# <option value></option>
# </select>
# </div>
# <div id="o2-unit-input-container" class="form-control-animation">
# <input id="o2UnitNumber" type="text" class="form-control" placeholder=" " aria-describedby="o2UnitNumber" maxlength="30" name="dwfrm_addressChecker_unitNumber" value maxLength="50" />
# <label class="form-control-label o2-unit-number-label" for="o2UnitNumber">
# Select or enter unit
# </label>
# </div>
# </div>
# </div>
# <div class="bf__agreement">
# <div class="agreement-select-wrapper">
# <div class="address-check__existing-user-wrapper">
# <div class="content-asset">
# <p><span class="address-check__existing-user"><span style="font-size:16px;">Are you a current CenturyLink customer with service at this address? </span></span></p>
# </div>
# </div>
# <div id="js-radio-btns-wrapper" class="radio-btns-wrapper">
# <div class="form-group custom-radio">
# <input type="radio" id="centurylink-existing-yes" class="custom-control-input" value="true" name="dwfrm_addressChecker_centurylinkExisting" value maxLength="2147483647" />
# <label for="centurylink-existing-yes" class="custom-control-label">
# Yes
# </label>
# <div class="invalid-feedback"></div>
# </div>
# <div class="form-group custom-radio">
# <input type="radio" id="centurylink-existing-no" class="custom-control-input" value="false" name="dwfrm_addressChecker_centurylinkExisting" value maxLength="2147483647" />
# <label for="centurylink-existing-no" class="custom-control-label">
# No
# </label>
# <div class="invalid-feedback"></div>
# </div>
# </div>
# </div>
# <div class="agreement-description">
# <div class="html-slot-container">
# <div class="icon__span icon__bm_warning">Have you heard? CenturyLink is transforming into Quantum Fiber! Moving your services to Quantum Fiber or making any changes to your current CenturyLink service(s) will remove any bundle discounts, promotional pricing, credits, or Price for Life offer. If you’d like to move forward with fiber internet, which does not currently offer bundle discounts, click “Check Availability”. If you currently have CenturyLink phone service, one of our agents will contact you to review available Quantum Fiber voice options after your Quantum Fiber internet order is placed.</div>
# </div>
# </div>
# </div>
# <div class="row form-row-last">
# <div class="col-12 text-top">
# <a href="javascript:void(0)" id="address-check__tooltip" data-container="body" data-toggle="popover" data-placement="top" class="form-instructional info-icon__click">
# <span id="address-check__tooltip-text" class="d-none">
# <div class="html-slot-container">
# We need your address to determine if we provide service to your exact location. Also, Internet speeds, pricing and services often differ from location to location. Quantum Fiber may use the address you entered to send you information customized to your area.
# </div>
# </span>
# Why do you need my address?
# </a>
# </div>
# <div class="col-7 text-left">
# <a href="https://fiber.q.com/fiber/s/login/" class="address-check__sign-link">Already a Quantum Fiber customer? Sign In</a>
# </div>
# <div class="col-5 text-right">
# <span class="form-desc"><span class="form-required-ast">*</span>required field</span>
# </div>
# </div>
# </div>
# </div>
# <div class="bf__main_gap"></div>
# </div>
# <div class="bf__btns">
# <div class="btn-group">
# <a id="addresscheck__back" href class="qf-btn qf-btn-secondary">Back</a>
# <button disabled id="adresscheck-submit" type="submit" class="qf-btn qf-btn-primary-action">Check availability</button>
# </div>
# </div>
# <div class="qf-modal modal fade" id="qfModalPurchase" tabindex="-1" role="dialog" aria-hidden="true">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="qf-modal__error modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Purchase now
# </h5>
# <button type="button" class="close js-btn-close" data-dismiss="modal" aria-label="Close">
# <span aria-hidden="true">
# <div class="icon icon__close " title="Close">
# <svg viewbox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.1428 10L19.3493 3.79362C20.2169 2.92572 20.2169 1.51882 19.3493 0.650922C18.4811 -0.216974 17.0744 -0.216974 16.2063 0.650922L9.99988 6.8573L3.7937 0.650922C2.92556 -0.216974 1.51864 -0.216974 0.650741 0.650922C-0.216914 1.51882 -0.216914 2.92572 0.650741 3.79362L6.85716 10L0.650741 16.2064C-0.216914 17.0743 -0.216914 18.4812 0.650741 19.3491C1.51889 20.217 2.92556 20.217 3.7937 19.3491L9.99988 13.1429L16.2063 19.3491C17.0742 20.217 18.4811 20.217 19.3493 19.3491C20.2169 18.4812 20.2169 17.0743 19.3493 16.2064L13.1428 10Z" fill="#788791" /></svg>
# </div>
# </span>
# </button>
# </div>
# <div class="modal-body">
# <div class="qf-modal__secondary-header"> <span>Quantum Fiber is bringing Fiber Internet to your neighborhood</span> </div> <div class="qf-modal__secondary-text"> <p>Fiber Internet is scheduled to be available at your address <strong>soon</span>.</strong></p> <p>To be one of the first customers to reserve your spot for Fiber Internet, select <strong>"Purchase now."</strong></p> </div>
# </div>
# <div class="modal-footer qf-modal__btns">
# <div class="btn-group">
# <button type="button" class="qf-btn qf-btn-primary-action js-btn-purchase">Purchase now</button>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="qf-modal modal fade" id="qfModalKnow" tabindex="-1" role="dialog" aria-hidden="true">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="qf-modal__error modal-content">
#
# <div class="modal-header">
# <h5 class="modal-title">
# Let me know
# </h5>
# <button type="button" class="close js-lmk-btn-close" data-dismiss="modal" aria-label="Close">
# <span aria-hidden="true">
# <div class="icon icon__close " title="Close">
# <svg viewbox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.1428 10L19.3493 3.79362C20.2169 2.92572 20.2169 1.51882 19.3493 0.650922C18.4811 -0.216974 17.0744 -0.216974 16.2063 0.650922L9.99988 6.8573L3.7937 0.650922C2.92556 -0.216974 1.51864 -0.216974 0.650741 0.650922C-0.216914 1.51882 -0.216914 2.92572 0.650741 3.79362L6.85716 10L0.650741 16.2064C-0.216914 17.0743 -0.216914 18.4812 0.650741 19.3491C1.51889 20.217 2.92556 20.217 3.7937 19.3491L9.99988 13.1429L16.2063 19.3491C17.0742 20.217 18.4811 20.217 19.3493 19.3491C20.2169 18.4812 20.2169 17.0743 19.3493 16.2064L13.1428 10Z" fill="#788791" /></svg>
# </div>
# </span>
# </button>
# </div>
# <div class="modal-body">
# <div class="qf-modal__secondary-header">
# <span>Quantum Fiber is bringing Fiber Internet to your neighborhood</span>
# </div>
# <div class="qf-modal__secondary-text">
# <p>Fiber Internet is scheduled to be available at your address on <strong>soon.</strong>.</p>
# <p>To be notified when Fiber Internet is available, or if you would like to see products that may be available now, select <strong>"Let me know."</strong></p>
# </div>
# </div>
# <div class="modal-footer qf-modal__btns">
# <div class="btn-group">
# <a href="/shop/notifyme" class="qf-btn qf-btn-primary-action">Let me know</a>
# </div>
# </div>
#
# </div>
# </div>
# </div>
# <input id="long" hidden name="dwfrm_addressChecker_long" value maxLength="100" />
# <input id="lat" hidden name="dwfrm_addressChecker_lat" value maxLength="100" />
# <input id="streetnumber" hidden name="dwfrm_addressChecker_streetnumber" value maxLength="100" />
# <input id="street" hidden value name="dwfrm_addressChecker_street" />
# <input id="city" hidden value name="dwfrm_addressChecker_city" />
# <input id="stateCode" hidden name="dwfrm_addressChecker_states_stateCode" />
# <input id="stateCodeLong" hidden value name="dwfrm_addressChecker_stateCodeLong" />
# <input id="zipcode" value hidden name="dwfrm_addressChecker_zipcode" />
# <input id="predirection" hidden value name="dwfrm_addressChecker_predirection" />
# <input id="postdirection" value hidden name="dwfrm_addressChecker_postdirection" />
# <input id="afstreetname" hidden value name="dwfrm_addressChecker_afstreetname" />
# <input id="afstreetsuffix" hidden value name="dwfrm_addressChecker_afstreetsuffix" />
# <input id="countrycode" hidden value name="dwfrm_addressChecker_countrycode" value maxLength="10" />
# <input id="addressGoogleFormatted" hidden name="dwfrm_addressChecker_addressGoogleFormatted" value maxLength="100" />
# <input id="isRooftop" hidden name="dwfrm_addressChecker_isRooftop" value maxLength="10" />
# <input id="mdu" hidden name="dwfrm_addressChecker_mdu" value maxLength="100" />
# <input id="addressId" hidden name="dwfrm_addressChecker_addressId" value maxLength="100" />
# <input id="o2_units" hidden name="dwfrm_addressChecker_o2__units" value maxLength="100" />
# <input id="addressKey" hidden name="dwfrm_addressChecker_addressKey" value maxLength="100" />
# <input type="hidden" name="csrf_token" value="JqC2vbR6hivrxyTwSZQIF5-sKJ2O0qkH1MCszCDHsJgSyAiDr2xNQMi0TH5182fHiO2S-vRYRlxRnJoxqcg1WSw-LhMo43w_3mgf_didpsyqjRokHtxLZUWQ6udnKpkJmLbZVxINd73qcfbuQMGW2zDJeXzSdGo5e95ow492fQdAUn_4Xqw=" />
# <input id="instantWifi" hidden name="null" value="null" />
# <input id="propertyId" hidden value name="dwfrm_addressChecker_propertyId" />
# <input id="workType" hidden value name="dwfrm_addressChecker_workType" />
# <input id="salescode" hidden name="salescode" encoding="off" />
# <input id="o2unitsKeyedIn" hidden name="o2unitsKeyedIn" encoding="off" />
# <input id="geo_type" hidden name="geo_type" encoding="off" />
# <input id="baseAddr" hidden />
# </form>
# <input type="hidden" id="o2Endpoint" value="https://centurylink-prod.apigee.net/v1-O2/" />
# <input type="hidden" id="o2APIKey" value="74rtvsz2HLMGSYKpBtu4JUbkEtabhps8" />
# <script>
#                     function  o2Response(response) {
#                         const event = new CustomEvent('o2Event', {detail: {'response':response}});
#                         document.dispatchEvent(event);
#                     }
#                     function  o2VariantResponse(response) {
#                         const eventVariant = new CustomEvent('o2EventVariant', {detail: {'response':response}});
#                         document.dispatchEvent(eventVariant);
#                     }
#                     function openDropdown(elementId) {
#                         function down() {
#                             var pos = $(this).offset();
#                             var len = $(this).find("option").length;
#                             if(len > 20) {
#                                 len = 20;
#                             }
#
#                             $(this).css("position", "absolute");
#                             $(this).css("zIndex", 9999);
#                             $(this).offset(pos);
#                             $(this).attr("size", len);
#                             $(this).unbind("focus", down);
#                             $(this).focus();
#                         }
#                         function up() {
#                             $(this).css("position", "static");
#                             $(this).attr("size", "1");
#                             $(this).unbind("change", up);
#                             $(this).focus();
#                         }
#                         $("#" + elementId).focus(down).blur(up).focus();
#                     }
#
#                     function mduResponse(response) {
#                         const event = new CustomEvent('mduEvent', {detail: {'response':response}});
#                         document.dispatchEvent(event);
#                         openDropdown('o2UnitsOptions');
#                         $('#o2UnitsOptions').on('change', function() {
#                             $(this).blur();
#                         });
#                     }
#                 </script>
# <div id="o2AppendScript"></div>
# </div>
# </div>
# </div>
# <div class="error-messaging"></div>
# <div class="modal-background"></div>
# <!--[if lt IE 10]>
# <script>//common/scripts.isml</script>
# <script defer type="text/javascript" src="/on/demandware.static/Sites-QFCC-Site/-/default/v1707242584047/js/main.js"></script>
#
#
#         <script defer type="text/javascript" src="/on/demandware.static/Sites-QFCC-Site/-/default/v1707242584047/js/addressChecker.js"
#
#             >
#         </script>
#
#
#
# <![endif]-->
# <span class="PLATFORM_CONSENT_TRACKING_DISABLED"></span>
# <div class="qf-modal modal fade" id="qfModalTimeExpired" tabindex="-1" role="dialog" aria-hidden="true" data-appointment-expired-time="1800000" data-redirect-url="/shop/install" data-validatesession-url="/on/demandware.store/Sites-QFCC-Site/default/Appointment-ValidateSession">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="qf-modal__error modal-content">
#
# <div class="modal-header">
# <h5 class="modal-title">
# Time Expired
# </h5>
# <a href="/shop/install" class="close" aria-label="Close">
# <span aria-hidden="true">
# <div class="icon icon__close " title="Close">
# <svg viewbox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.1428 10L19.3493 3.79362C20.2169 2.92572 20.2169 1.51882 19.3493 0.650922C18.4811 -0.216974 17.0744 -0.216974 16.2063 0.650922L9.99988 6.8573L3.7937 0.650922C2.92556 -0.216974 1.51864 -0.216974 0.650741 0.650922C-0.216914 1.51882 -0.216914 2.92572 0.650741 3.79362L6.85716 10L0.650741 16.2064C-0.216914 17.0743 -0.216914 18.4812 0.650741 19.3491C1.51889 20.217 2.92556 20.217 3.7937 19.3491L9.99988 13.1429L16.2063 19.3491C17.0742 20.217 18.4811 20.217 19.3493 19.3491C20.2169 18.4812 20.2169 17.0743 19.3493 16.2064L13.1428 10Z" fill="#788791" /></svg>
# </div>
# </span>
# </a>
# </div>
# <div class="modal-body">
# <div class="qf-modal__secondary-header"> <span>Appointment times are held for 30 minutes.</span> </div> <div class="qf-modal__secondary-text"> <p>We can only hold time slots for appointments for 30 minutes at a time. Please select a new timeslot for your appointment.</p> </div>
# </div>
# <div class="modal-footer qf-modal__btns">
# <div class="btn-group">
# <a href="/shop/install" class="qf-btn qf-btn-primary-action">Select New Time</a>
# </div>
# </div>
#
# </div>
# </div>
# </div>
# <div class="qf-modal modal fade" id="qfModalSessionExpired" tabindex="-1" role="dialog" aria-hidden="true" data-redirect-url="/shop">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="qf-modal__error modal-content">
#
# <div class="modal-header">
# <h5 class="modal-title">
# Session Expired
# </h5>
# <a href="/shop" class="close" aria-label="Close">
# <span aria-hidden="true">
# <div class="icon icon__close " title="Close">
# <svg viewbox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.1428 10L19.3493 3.79362C20.2169 2.92572 20.2169 1.51882 19.3493 0.650922C18.4811 -0.216974 17.0744 -0.216974 16.2063 0.650922L9.99988 6.8573L3.7937 0.650922C2.92556 -0.216974 1.51864 -0.216974 0.650741 0.650922C-0.216914 1.51882 -0.216914 2.92572 0.650741 3.79362L6.85716 10L0.650741 16.2064C-0.216914 17.0743 -0.216914 18.4812 0.650741 19.3491C1.51889 20.217 2.92556 20.217 3.7937 19.3491L9.99988 13.1429L16.2063 19.3491C17.0742 20.217 18.4811 20.217 19.3493 19.3491C20.2169 18.4812 20.2169 17.0743 19.3493 16.2064L13.1428 10Z" fill="#788791" /></svg>
# </div>
# </span>
# </a>
# </div>
# <div class="modal-body">
# <div class="qf-modal__secondary-header"> <span>Oops! It looks like your session has expired.</span> </div> <div class="qf-modal__secondary-text"> <p>We apologize for the inconvenience, but we’ll take you to the beginning so you can make your selections again.</p> </div>
# </div>
# <div class="modal-footer qf-modal__btns">
# <div class="btn-group">
# <a href="/shop" class="qf-btn qf-btn-primary-action">Continue</a>
# </div>
# </div>
#
# </div>
# </div>
# </div>
# <div class="qf-modal modal fade" id="qf-modal-error" tabindex="-1" role="dialog" aria-hidden="true" data-failed-to-load-timeout="55000">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="qf-modal__error modal-content">
# <div class="modal-header">
# <div class="modal-title">
# Failed to Load
# </div>
# <button type="button" class="close" data-dismiss="modal" aria-label="Close">
# <span aria-hidden="true">
# <div class="icon icon__close " title="Close">
# <svg viewbox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.1428 10L19.3493 3.79362C20.2169 2.92572 20.2169 1.51882 19.3493 0.650922C18.4811 -0.216974 17.0744 -0.216974 16.2063 0.650922L9.99988 6.8573L3.7937 0.650922C2.92556 -0.216974 1.51864 -0.216974 0.650741 0.650922C-0.216914 1.51882 -0.216914 2.92572 0.650741 3.79362L6.85716 10L0.650741 16.2064C-0.216914 17.0743 -0.216914 18.4812 0.650741 19.3491C1.51889 20.217 2.92556 20.217 3.7937 19.3491L9.99988 13.1429L16.2063 19.3491C17.0742 20.217 18.4811 20.217 19.3493 19.3491C20.2169 18.4812 20.2169 17.0743 19.3493 16.2064L13.1428 10Z" fill="#788791" /></svg>
# </div>
# </span>
# </button>
# </div>
# <div class="modal-body">
# <div class="qf-modal__secondary-header"> <div class="icon icon__warning "> <svg viewBox="0 0 20 21" fill="none" xmlns="http://www.w3.org/2000/svg"> <path d="M0 20.6572H20L10 0.657227L0 20.6572ZM10.9091 17.4993H9.09091V15.3941H10.9091V17.4993ZM10.9091 13.2888H9.09091V9.07828H10.9091V13.2888Z" fill="#FFB464"></path> </svg> </div> <span>Looks like we ran into a problem.</span> </div> <div class="qf-modal__secondary-text"> <span>While trying to load the experience for you, we ran into an issue. The most likely cause is a problem with the internet connection. Please verify your connection and refresh the page to try again.</span> </div>
# </div>
# <div class="modal-footer qf-modal__btns">
# <div class="qf-modal__error-message">
# </div>
# <div class="btn-group">
# <button type="button" class="qf-btn qf-btn-secondary" data-dismiss="modal">Back</button>
# <button type="button" class="qf-btn qf-btn-primary-action js-refresh-btn">Refresh Page</button>
# </div>
# </div>
# </div>
# </div>
# <div id="qf-modal-error-dummy" class="d-none"></div>
# </div>
# <div class="qf-modal modal fade" id="qfModalPromoDetails" tabindex="-1" role="dialog" aria-hidden="true">
# <div class="modal-dialog modal-dialog-centered" role="document">
# <div class="qf-modal__error modal-content">
# <div class="modal-header">
# <h5 class="modal-title">
# Amazon Fire TV Stick Offer
# </h5>
# <button type="button" class="close" data-dismiss="modal" aria-label="Close">
# <span aria-hidden="true">
# <div class="icon icon__close " title="Close">
# <svg viewbox="0 0 20 20" fill="none" xmlns="http://www.w3.org/2000/svg"><path fill-rule="evenodd" clip-rule="evenodd" d="M13.1428 10L19.3493 3.79362C20.2169 2.92572 20.2169 1.51882 19.3493 0.650922C18.4811 -0.216974 17.0744 -0.216974 16.2063 0.650922L9.99988 6.8573L3.7937 0.650922C2.92556 -0.216974 1.51864 -0.216974 0.650741 0.650922C-0.216914 1.51882 -0.216914 2.92572 0.650741 3.79362L6.85716 10L0.650741 16.2064C-0.216914 17.0743 -0.216914 18.4812 0.650741 19.3491C1.51889 20.217 2.92556 20.217 3.7937 19.3491L9.99988 13.1429L16.2063 19.3491C17.0742 20.217 18.4811 20.217 19.3493 19.3491C20.2169 18.4812 20.2169 17.0743 19.3493 16.2064L13.1428 10Z" fill="#788791" /></svg>
# </div>
# </span>
# </button>
# </div>
# <div class="modal-body">
# <div class="qf-modal__secondary-text" id="qf-modal__promoDetails">
# <p>
# Limited time offer is available through Amazon.com. Offer requires new, qualifying residential Quantum Fiber customers to sign up for a qualifying up to 940 Mbps Internet service plan to be eligible for an Amazon Fire TV Stick 4K Max (“Device”), valued at $54.99. One Device per customer/account. Customer will be sent an email, after the order is completed, with instructions on how to redeem offer. Offer must be redeemed within 14 days of the date on the redemption email to receive Device. Customer must have a free Amazon account to redeem offer. Device is provided as-is, without any warranties or guarantees beyond the manufacturer standard warranty. Subscriptions will apply to certain third-party streaming and gaming services in order to access. Offer is not stackable with other Quantum Fiber offers. Quantum Fiber may change, cancel, or substitute offers and services, or vary them by service area, at its sole discretion without notice. Additional restrictions may apply.
# </p>
# <img class="promoDetails-image" alt="img" width="303" height="260" src="https://www.quantumfiber.com/on/demandware.static/-/Sites-QFCC-Library/default/dwb67f4536/telco/modals/promoDetailsImage.png" />
# </div>
# <style>
#     #qf-modal__promoDetails .promoDetails-image {
#       margin: 0 auto;
#       display: block;
#     }
# #qf-modal__promoDetails a {cursor: default}
#
#     .qf-modal__secondary-heade-text {
#           margin-left:7px;
#     }
#
#
#     @media only screen and (min-width: 768px) {
#       #qf-modal__promoDetails {
#         display: flex;
#                     overflow-y: scroll;
#                     height: 330px;
#       }
#       #qf-modal__promoDetails p {
#         padding-right: 38px;
#       }
#     }
#     </style>
# </div>
# </div>
# </div>
# </div>
#
# <script type="text/javascript">//<!--
# /* <![CDATA[ */
# function trackPage() {
#     try{
#         var trackingUrl = "https://www.quantumfiber.com/on/demandware.store/Sites-QFCC-Site/default/__Analytics-Start";
#         var dwAnalytics = dw.__dwAnalytics.getTracker(trackingUrl);
#         if (typeof dw.ac == "undefined") {
#             dwAnalytics.trackPageView();
#         } else {
#             dw.ac.setDWAnalytics(dwAnalytics);
#         }
#     }catch(err) {};
# }
# /* ]]> */
# // -->
# </script>
# <script type="text/javascript" src="/on/demandware.static/Sites-QFCC-Site/-/default/v1707242584047/internal/jscript/dwanalytics-22.2.js" async="async" onload="trackPage()"></script>
#
# <script src="/on/demandware.static/Sites-QFCC-Site/-/default/v1707242584047/internal/jscript/dwac-21.7.js" type="text/javascript" async="async"></script>
# <script src="https://cdn.cquotient.com/js/v2/gretel.min.js" type="text/javascript" async="async"></script>
# </body>
# </html>

# %%
def chunker(seq, size):
    return list(seq[pos:pos + size] for pos in range(0, len(seq), size))

# %%
import time
# import os
import logging
# print(os.path.exists('test.log'))
# print(os.getcwd())
logging.basicConfig(filename='test.log', encoding='utf-8', level=logging.DEBUG, filemode='a')
run_num = 100
adr_chunk = [1, 2, 3, 4]
# logging.info('AAAA')
logging.info('%s: Run %s with %s addresses COMPLETE.',
             time.strftime("%H:%M:%S", time.localtime()), run_num, len(adr_chunk))
print(
    f'{time.strftime("%H:%M:%S", time.localtime())}: Run {run_num} with '
    f'{len(adr_chunk)} addresses COMPLETE.'
)
# print('%s: Run %s with %s addresses COMPLETE.' % (time.strftime("%H:%M:%S", time.localtime()), run_num, len(adr_chunk)))
# Out:
# 13:35:38: Run 100 with 4 addresses COMPLETE.

# %%
addresses = ['a1', 'a2', 'a3', 'a4', 'a5', 'a6', 'a7', 'a8']

for group in chunker(addresses, 5):
    print(group)

# %%
with open('../res/adrs_for_quantum.csv') as adrs:
    a = csv.reader(adrs)
    for ad in a:
        print(ad[0])
# Out:
# 845 S  SULLIVAN ST SEATTLE WA 98108 USA
# 7803 8TH AVE S SEATTLE WA 98108 USA
# 819 S  THISTLE ST SEATTLE WA 98108 USA
# 749 S  ROSE ST SEATTLE WA 98108 USA
# 834 S  CLOVERDALE ST SEATTLE WA 98108 USA
# 740 S  ELMGROVE ST SEATTLE WA 98108 USA
# 543 S  MONROE ST SEATTLE WA 98108 USA
# 7245 2ND AVE S SEATTLE WA 98108 USA
# 823 S  KENYON ST SEATTLE WA 98108 USA
# 853 S  ROSE ST SEATTLE WA 98108 USA
# 730 S  CHICAGO ST SEATTLE WA 98108 USA
# 7701 5TH AVE S SEATTLE WA 98108 USA
# 8503 10TH AVE S SEATTLE WA 98108 USA
# 1720 SW  106TH ST SEATTLE WA 98146 USA
# 10044 19TH AVE SW SEATTLE WA 98146 USA
# 10040 21ST AVE SW SEATTLE WA 98146 USA
# 10416 18TH AVE SW SEATTLE WA 98146 USA
# 9842 18TH AVE SW SEATTLE WA 98106 USA
# 10242 17TH AVE SW SEATTLE WA 98146 USA
# 9816 21ST AVE SW SEATTLE WA 98106 USA
# 10270 26TH AVE SW SEATTLE WA 98146 USA
# 9841 26TH AVE SW SEATTLE WA 98106 USA
# 2230 SW  104TH ST SEATTLE WA 98146 USA
# 9638 22ND AVE SW SEATTLE WA 98106 USA
# 2218 SW  103RD PL SEATTLE WA 98146 USA
# 9807 28TH AVE SW SEATTLE WA 98126 USA
# 2120 SW  104TH ST SEATTLE WA 98146 USA
# 10239 26TH AVE SW SEATTLE WA 98146 USA
# 10434 26TH AVE SW SEATTLE WA 98146 USA
# 10402 25TH AVE SW SEATTLE WA 98146 USA
# 6051 NE  135TH ST SEATTLE WA 98034 USA
# 12945 64TH AVE NE SEATTLE WA 98034 USA
# 12453 HOLMES POINT DR NE SEATTLE WA 98034 USA
# 7233 NE  127TH ST SEATTLE WA 98034 USA
# 12519 64TH AVE NE SEATTLE WA 98034 USA
# 13505 72ND AVE NE SEATTLE WA 98034 USA
# 13323 69TH AVE NE SEATTLE WA 98034 USA
# 13717 70TH AVE NE SEATTLE WA 98034 USA
# 12918 72ND AVE NE SEATTLE WA 98034 USA
# 12933 76TH AVE NE SEATTLE WA 98034 USA
# 7135 NE  132ND LN SEATTLE WA 98034 USA
# 12947 72ND AVE NE SEATTLE WA 98034 USA
# 7002 NE  139TH ST SEATTLE WA 98034 USA
# 12429 68TH AVE NE SEATTLE WA 98034 USA
# 12845 HOLIDAY DR NE SEATTLE WA 98034 USA
# 6037 NE  135TH ST SEATTLE WA 98034 USA
# 12433 68TH AVE NE SEATTLE WA 98034 USA
# 6951 NE  139TH ST SEATTLE WA 98034 USA
# 7786 NE  122ND LN SEATTLE WA 98034 USA
# 11645 HOLMES POINT DR NE SEATTLE WA 98034 USA
# 7791 NE  122ND LN SEATTLE WA 98034 USA
# 11625 HOLMES POINT DR NE SEATTLE WA 98034 USA
# 11264 CHAMPAGNE POINT RD NE SEATTLE WA 98034 USA
# 7615 NE  123RD ST SEATTLE WA 98034 USA
# 11144 79TH PL NE SEATTLE WA 98034 USA
# 7237 NE  121ST PL SEATTLE WA 98034 USA
# 7824 NE  112TH ST SEATTLE WA 98034 USA
# 7772 NE  122ND LN SEATTLE WA 98034 USA
# 11613 HOLMES POINT DR NE SEATTLE WA 98034 USA
# 10907 80TH PL NE SEATTLE WA 98034 USA
# 7460 NE  122ND ST SEATTLE WA 98034 USA
# 1245 NE  CAMPUS PKWY SEATTLE WA 98105 USA
# 1824 15TH AVE S SEATTLE WA 98144 USA
# 1724 13TH AVE S SEATTLE WA 98144 USA
# 2300 21ST AVE S SEATTLE WA 98144 USA
# 2330 22ND AVE S SEATTLE WA 98144 USA
# 1750 VALENTINE PL S SEATTLE WA 98144 USA
# 11332 BARTLETT AVE NE SEATTLE WA 98125 USA
# 10720 BARTLETT AVE NE SEATTLE WA 98125 USA
# 11326 40TH AVE NE SEATTLE WA 98125 USA
# 11054 38TH AVE NE SEATTLE WA 98125 USA
# 10738 BARTLETT AVE NE SEATTLE WA 98125 USA
# 10550 41ST PL NE SEATTLE WA 98125 USA
# 11302 ALTON AVE NE SEATTLE WA 98125 USA
# 11015 ALTON AVE NE SEATTLE WA 98125 USA
# 10717 SAND POINT WAY NE SEATTLE WA 98125 USA
# 3840 NE  113TH ST SEATTLE WA 98125 USA
# 3811 NE  110TH ST SEATTLE WA 98125 USA
# 10718 ALTON AVE NE SEATTLE WA 98125 USA
# 4015 NE  113TH ST SEATTLE WA 98125 USA
# 11032 38TH AVE NE SEATTLE WA 98125 USA
# 11314 35TH AVE NE SEATTLE WA 98125 USA
# 10749 SAND POINT WAY NE SEATTLE WA 98125 USA
# 11320 38TH AVE NE SEATTLE WA 98125 USA
# 11332 36TH AVE NE SEATTLE WA 98125 USA
# 11320 35TH AVE NE SEATTLE WA 98125 USA
# 10468 16TH AVE S SEATTLE WA 98168 USA
# 410 2ND AVE EXT  S SEATTLE WA 98104 USA
# 406 2ND AVE EXT  S SEATTLE WA 98104 USA
# 219 2ND AVE S SEATTLE WA 98104 USA
# 155 YESLER WAY SEATTLE WA 98104 USA
# 172 S  WASHINGTON ST SEATTLE WA 98104 USA
# 117 S  WASHINGTON ST SEATTLE WA 98104 USA
# 65 S  WASHINGTON ST SEATTLE WA 98104 USA
# 126 S  JACKSON ST SEATTLE WA 98104 USA
# 110 ALASKAN WAY S SEATTLE WA 98104 USA
# 81 YESLER WAY SEATTLE WA 98104 USA
# 217 1ST AVE S SEATTLE WA 98104 USA
# 85 YESLER WAY SEATTLE WA 98104 USA
# 112 S  WASHINGTON ST SEATTLE WA 98104 USA
# 301 ALASKAN WAY S SEATTLE WA 98104 USA
# 222 3RD AVE S SEATTLE WA 98104 USA
# 217 1ST AVE S SEATTLE WA 98104 USA
# 802 N  46TH ST SEATTLE WA 98103 USA
# 717 N  47TH ST SEATTLE WA 98103 USA
# 516 N  46TH ST SEATTLE WA 98103 USA
# 4919 PHINNEY AVE N SEATTLE WA 98103 USA
# 810 N  48TH ST SEATTLE WA 98103 USA
# 4712 FREMONT AVE N SEATTLE WA 98103 USA
# 716 N  49TH ST SEATTLE WA 98103 USA
# 714 N  46TH ST SEATTLE WA 98103 USA
# 331 N  50TH ST SEATTLE WA 98103 USA
# 4600 PHINNEY AVE N SEATTLE WA 98103 USA
# 4605 AURORA AVE N SEATTLE WA 98103 USA
# 4811 PHINNEY AVE N SEATTLE WA 98103 USA
# 828 N  47TH ST SEATTLE WA 98103 USA
# 4903 LINDEN AVE N SEATTLE WA 98103 USA
# 515 N  50TH ST SEATTLE WA 98103 USA
# 4616 LINDEN AVE N SEATTLE WA 98103 USA
# 707 N  48TH ST SEATTLE WA 98103 USA
# 4602 EVANSTON AVE N SEATTLE WA 98103 USA
# 4500 PHINNEY AVE N SEATTLE WA 98103 USA
# 2631 NW  56TH ST SEATTLE WA 98107 USA
# 2636 NW  56TH ST SEATTLE WA 98107 USA
# 2609 NW  57TH ST SEATTLE WA 98107 USA
# 2637 NW  58TH ST SEATTLE WA 98107 USA
# 2631 NW  56TH ST SEATTLE WA 98107 USA
# 2441 NW  58TH ST SEATTLE WA 98107 USA
# 2651 NW  56TH ST SEATTLE WA 98107 USA
# 2643 NW  57TH ST SEATTLE WA 98107 USA
# 2606 NW  56TH ST SEATTLE WA 98107 USA
# 2411 NW  58TH ST SEATTLE WA 98107 USA
# 2633 NW  57TH ST SEATTLE WA 98107 USA
# 2405 NW  57TH ST SEATTLE WA 98107 USA
# 2609 NW  56TH ST SEATTLE WA 98107 USA
# 2605 NW  58TH ST SEATTLE WA 98107 USA
# 1251 E  OLIVE ST SEATTLE WA 98122 USA
# 4400 86TH AVE SE SEATTLE WA 98040 USA
# 4135 80TH AVE SE SEATTLE WA 98040 USA
# 4030 86TH AVE SE SEATTLE WA 98040 USA
# 8340 MERRIMOUNT DR SEATTLE WA 98040 USA
# 8310 SE  41ST ST SEATTLE WA 98040 USA
# 4106 78TH AVE SE SEATTLE WA 98040 USA
# 4121 80TH AVE SE SEATTLE WA 98040 USA
# 20 HOLLY LN SEATTLE WA 98040 USA
# 4162 W  MERCER WAY SEATTLE WA 98040 USA
# 4244 83RD AVE SE SEATTLE WA 98040 USA
# 8415 SE  45TH ST SEATTLE WA 98040 USA
# 4323 86TH AVE SE SEATTLE WA 98040 USA
# 4632 86TH AVE SE SEATTLE WA 98040 USA
# 4840 FOREST AVE SE SEATTLE WA 98040 USA
# 4316 ISLAND CREST WAY SEATTLE WA 98040 USA
# 12 WEMBLEY LN SEATTLE WA 98040 USA
# 4455 FOREST AVE SE SEATTLE WA 98040 USA
# 4228 W  MERCER WAY SEATTLE WA 98040 USA
# 4646 FOREST AVE SE SEATTLE WA 98040 USA
# 4459 FOREST AVE SE SEATTLE WA 98040 USA
# 4702 86TH AVE SE SEATTLE WA 98040 USA
# 4 WEMBLEY LN SEATTLE WA 98040 USA
# 4212 W  MERCER WAY SEATTLE WA 98040 USA
# 6506 28TH AVE NW SEATTLE WA 98117 USA
# 2636 NW  64TH ST SEATTLE WA 98107 USA
# 2428 NW  63RD ST SEATTLE WA 98107 USA
# 6511 25TH AVE NW SEATTLE WA 98117 USA
# 2655 NW  64TH ST SEATTLE WA 98107 USA
# 2426 NW  64TH ST SEATTLE WA 98107 USA
# 2656 NW  63RD ST SEATTLE WA 98107 USA
# 2838 NW  65TH ST SEATTLE WA 98117 USA
# 6724 27TH AVE NW SEATTLE WA 98117 USA
# 2829 NW  69TH ST SEATTLE WA 98117 USA
# 6301 26TH AVE NW SEATTLE WA 98107 USA
# 6524 28TH AVE NW SEATTLE WA 98117 USA
# 2762 NW  65TH ST SEATTLE WA 98117 USA
# 2428 NW  63RD ST SEATTLE WA 98107 USA
# 2850 NW  69TH ST SEATTLE WA 98117 USA
# 6527 27TH AVE NW SEATTLE WA 98117 USA
# 2836 NW  68TH ST SEATTLE WA 98117 USA
# 6728 EARL AVE NW SEATTLE WA 98117 USA
# 6506 28TH AVE NW SEATTLE WA 98117 USA
# 6541 25TH AVE NW SEATTLE WA 98117 USA
# 2406 NW  63RD ST SEATTLE WA 98107 USA
# 6404 28TH AVE NW SEATTLE WA 98107 USA
# 6703 25TH AVE NW SEATTLE WA 98117 USA
# 2515 NW  67TH ST SEATTLE WA 98117 USA
# 2850 NW  65TH ST SEATTLE WA 98117 USA
# 2636 NW  64TH ST SEATTLE WA 98107 USA
# 2827 NW  70TH ST SEATTLE WA 98117 USA
# 6311 26TH AVE NW SEATTLE WA 98107 USA
# 6554 25TH AVE NW SEATTLE WA 98117 USA
# 6539 24TH AVE NW SEATTLE WA 98117 USA
# 6308 26TH AVE NW SEATTLE WA 98107 USA
# 2762 NW  65TH ST SEATTLE WA 98117 USA
# 2655 NW  64TH ST SEATTLE WA 98107 USA
# 2424 NW  60TH ST SEATTLE WA 98107 USA
# 2429 NW  60TH ST SEATTLE WA 98107 USA
# 2806 NW  62ND ST SEATTLE WA 98107 USA
# 2830 NW  62ND ST SEATTLE WA 98107 USA
# 2616 NW  59TH ST SEATTLE WA 98107 USA
# 2412 NW  61ST ST SEATTLE WA 98107 USA
# 2632 NW  59TH ST SEATTLE WA 98107 USA
# 2851 NW  64TH ST SEATTLE WA 98107 USA
# 5817 28TH AVE NW SEATTLE WA 98107 USA
# 2602 NW  62ND ST SEATTLE WA 98107 USA
# 2417 NW  60TH ST SEATTLE WA 98107 USA
# 2799 NW  BRYGGER PL SEATTLE WA 98107 USA
# 2430 NW  62ND ST SEATTLE WA 98107 USA
# 2801 NW  61ST ST SEATTLE WA 98107 USA
# 2837 NW  60TH ST SEATTLE WA 98107 USA
# 2822 NW  60TH ST SEATTLE WA 98107 USA
# 2807 NW  61ST ST SEATTLE WA 98107 USA
# 3012 NW  61ST ST SEATTLE WA 98107 USA
# 3220 NW  69TH ST SEATTLE WA 98117 USA
# 3012 NW  68TH ST SEATTLE WA 98117 USA
# 3012 NW  64TH ST SEATTLE WA 98107 USA
# 3243 NW  61ST ST SEATTLE WA 98107 USA
# 3017 NW  61ST ST SEATTLE WA 98107 USA
# 6316 32ND AVE NW SEATTLE WA 98107 USA
# 3257 NW  62ND ST SEATTLE WA 98107 USA
# 3030 NW  66TH ST SEATTLE WA 98117 USA
# 3255 NW  62ND ST SEATTLE WA 98107 USA
# 3011 NW  70TH ST SEATTLE WA 98117 USA
# 3013 NW  65TH ST SEATTLE WA 98117 USA
# 6720 34TH AVE NW SEATTLE WA 98117 USA
# 3245 NW  62ND ST SEATTLE WA 98107 USA
# 3044 NW  69TH ST SEATTLE WA 98117 USA
# 3047 NW  62ND ST SEATTLE WA 98107 USA
# 3019 NW  66TH ST SEATTLE WA 98117 USA
# 3016 NW  64TH ST SEATTLE WA 98107 USA
# 6412 32ND AVE NW SEATTLE WA 98107 USA
# 6108 34TH AVE NW SEATTLE WA 98107 USA
# 3027 NW  67TH ST SEATTLE WA 98117 USA
# 3242 NW  62ND ST SEATTLE WA 98107 USA
# 3030 NW  63RD ST SEATTLE WA 98107 USA
# 3232 NW  64TH ST SEATTLE WA 98107 USA
# 6735 32ND AVE NW SEATTLE WA 98117 USA
# 3021 NW  64TH ST SEATTLE WA 98107 USA
# 915 E  PINE ST SEATTLE WA 98122 USA
# 1518 10TH AVE SEATTLE WA 98122 USA
# 8423 40TH AVE SW SEATTLE WA 98136 USA
# 4319 SW  TRENTON ST SEATTLE WA 98136 USA
# 8462 TILLICUM RD SW SEATTLE WA 98136 USA
# 4445 SW  KENYON PL SEATTLE WA 98136 USA
# 8312 FAUNTLEROY WAY SW SEATTLE WA 98136 USA
# 8659 FAUNTLEE CRST SW SEATTLE WA 98136 USA
# 3716 SW  BARTON ST SEATTLE WA 98126 USA
# 8862 42ND AVE SW SEATTLE WA 98136 USA
# 8416 41ST AVE SW SEATTLE WA 98136 USA
# 4500 SW  HEMLOCK WAY SEATTLE WA 98136 USA
# 8036 FAUNTLEROY WAY SW SEATTLE WA 98136 USA
# 8323 46TH AVE SW SEATTLE WA 98136 USA
# 8865 42ND AVE SW SEATTLE WA 98136 USA
# 8303 46TH AVE SW SEATTLE WA 98136 USA
# 8436 TILLICUM RD SW SEATTLE WA 98136 USA
# 4340 SW  CONCORD ST SEATTLE WA 98136 USA
# 8060 DIBBLE AVE NW SEATTLE WA 98117 USA
# 7332 9TH AVE NW SEATTLE WA 98117 USA
# 902 NW  75TH ST SEATTLE WA 98117 USA
# 7302 11TH AVE NW SEATTLE WA 98117 USA
# 8060 DIBBLE AVE NW SEATTLE WA 98117 USA
# 7307 8TH AVE NW SEATTLE WA 98117 USA
# 8417 8TH AVE NW SEATTLE WA 98117 USA
# 7321 DIBBLE AVE NW SEATTLE WA 98117 USA
# 7025 10TH AVE NW SEATTLE WA 98117 USA
# 8211 8TH AVE NW SEATTLE WA 98117 USA
# 7742 11TH AVE NW SEATTLE WA 98117 USA
# 8311 8TH AVE NW SEATTLE WA 98117 USA
# 7506 DIBBLE AVE NW SEATTLE WA 98117 USA
# 7515 9TH AVE NW SEATTLE WA 98117 USA
# 7517 9TH AVE NW SEATTLE WA 98117 USA
# 7342 10TH AVE NW SEATTLE WA 98117 USA
# 8342 9TH AVE NW SEATTLE WA 98117 USA
# 7039 8TH AVE NW SEATTLE WA 98117 USA
# 7552 11TH AVE NW SEATTLE WA 98117 USA
# 8409 8TH AVE NW SEATTLE WA 98117 USA
# 7336 11TH AVE NW SEATTLE WA 98117 USA
# 1012 NW  80TH ST SEATTLE WA 98117 USA
# 854 NW  70TH ST SEATTLE WA 98117 USA
# 7329 8TH AVE NW SEATTLE WA 98117 USA
# 8013 8TH AVE NW SEATTLE WA 98117 USA
# 7510 10TH AVE NW SEATTLE WA 98117 USA
# 7542 9TH AVE NW SEATTLE WA 98117 USA
# 8069 9TH AVE NW SEATTLE WA 98117 USA
# 7720 10TH AVE NW SEATTLE WA 98117 USA
# 7056 9TH AVE NW SEATTLE WA 98117 USA
# 8303 9TH AVE NW SEATTLE WA 98117 USA
# 7023 9TH AVE NW SEATTLE WA 98117 USA
# 7346 10TH AVE NW SEATTLE WA 98117 USA
# 4032 SW  OTHELLO ST SEATTLE WA 98136 USA
# 7010 CALIFORNIA AVE SW SEATTLE WA 98136 USA
# 7208 CALIFORNIA AVE SW SEATTLE WA 98136 USA
# 7350 CALIFORNIA AVE SW SEATTLE WA 98136 USA
# 7608 44TH AVE SW SEATTLE WA 98136 USA
# 3938 SW  MONROE ST SEATTLE WA 98136 USA
# 7604 CALIFORNIA AVE SW SEATTLE WA 98136 USA
# 7608 44TH AVE SW SEATTLE WA 98136 USA
# 4142 SW  MONROE ST SEATTLE WA 98136 USA
# 3930 SW  HOLDEN ST SEATTLE WA 98136 USA
# 7706 44TH AVE SW SEATTLE WA 98136 USA
# 3936 SW  ROSE ST SEATTLE WA 98136 USA
# 8304 CALIFORNIA AVE SW SEATTLE WA 98136 USA
# 4127 SW  PORTLAND ST SEATTLE WA 98136 USA
# 3940 SW  KENYON ST SEATTLE WA 98136 USA
# 7554 44TH AVE SW SEATTLE WA 98136 USA
# 3924 SW  HOLDEN ST SEATTLE WA 98136 USA
# 4115 SW  ROSE ST SEATTLE WA 98136 USA
# 3957 SW  HOLDEN ST SEATTLE WA 98136 USA
# 4506 SW  AUSTIN ST SEATTLE WA 98136 USA
# 7141 CALIFORNIA AVE SW SEATTLE WA 98136 USA
# 7312 BLAKE PL SW SEATTLE WA 98136 USA
# 7328 WRIGHT AVE SW SEATTLE WA 98136 USA
# 7055 BEACH DR SW SEATTLE WA 98136 USA
# 4506 SW  AUSTIN ST SEATTLE WA 98136 USA
# 7329 VASHON PL SW SEATTLE WA 98136 USA
# 7135 BEACH DR SW SEATTLE WA 98136 USA
# 7031 BEACH DR SW SEATTLE WA 98136 USA
# 7051 LINCOLN PARK WAY SW SEATTLE WA 98136 USA
# 7726 45TH AVE SW SEATTLE WA 98136 USA
# 7721 44TH AVE SW SEATTLE WA 98136 USA
# 7552 45TH AVE SW SEATTLE WA 98136 USA
# 7059 BEACH DR SW SEATTLE WA 98136 USA
# 8603 FAUNTLEROY WAY SW SEATTLE WA 98136 USA
# 7101 SYLVAN LN SW SEATTLE WA 98136 USA
# 7325 47TH AVE SW SEATTLE WA 98136 USA
# 4618 SW  OTHELLO ST SEATTLE WA 98136 USA
# 7137 45TH AVE SW SEATTLE WA 98136 USA
# 4822 SW  OTHELLO ST SEATTLE WA 98136 USA
# 7312 BLAKE PL SW SEATTLE WA 98136 USA
# 307 FAIRVIEW AVE N SEATTLE WA 98109 USA
# 2735 61ST AVE SE SEATTLE WA 98040 USA
# 3655 73RD AVE SE SEATTLE WA 98040 USA
# 3034 61ST AVE SE SEATTLE WA 98040 USA
# 3453 74TH AVE SE SEATTLE WA 98040 USA
# 3219 W  MERCER WAY SEATTLE WA 98040 USA
# 3259 67TH AVE SE SEATTLE WA 98040 USA
# 3318 72ND AVE SE SEATTLE WA 98040 USA
# 4047 W  MERCER WAY SEATTLE WA 98040 USA
# 2718 60TH AVE SE SEATTLE WA 98040 USA
# 3442 72ND PL SE SEATTLE WA 98040 USA
# 6905 SE  34TH ST SEATTLE WA 98040 USA
# 3208 73RD AVE SE SEATTLE WA 98040 USA
# 2712 60TH AVE SE SEATTLE WA 98040 USA
# 3011 61ST AVE SE SEATTLE WA 98040 USA
# 2451 60TH AVE SE SEATTLE WA 98040 USA
# 3449 74TH AVE SE SEATTLE WA 98040 USA
# 3621 W  MERCER WAY SEATTLE WA 98040 USA
# 4111 BOULEVARD PL SEATTLE WA 98040 USA
# 3865 W  MERCER WAY SEATTLE WA 98040 USA
# 3428 W  MERCER WAY SEATTLE WA 98040 USA
# 2220 82ND AVE SE SEATTLE WA 98040 USA
# 2234 81ST AVE SE SEATTLE WA 98040 USA
# 1845 72ND AVE SE SEATTLE WA 98040 USA
# 2453 84TH AVE SE SEATTLE WA 98040 USA
# 7214 N  MERCER WAY SEATTLE WA 98040 USA
# 2243 80TH AVE SE SEATTLE WA 98040 USA
# 1855 W  MERCER WAY SEATTLE WA 98040 USA
# 2226 81ST AVE SE SEATTLE WA 98040 USA
# 7432 N  MERCER WAY SEATTLE WA 98040 USA
# 7827 SE  22ND PL SEATTLE WA 98040 USA
# 2242 81ST AVE SE SEATTLE WA 98040 USA
# 2205 82ND AVE SE SEATTLE WA 98040 USA
# 7704 GREENWOOD AVE N SEATTLE WA 98103 USA
# 542 N  80TH ST SEATTLE WA 98103 USA
# 7704 GREENWOOD AVE N SEATTLE WA 98103 USA
# 906 N  77TH ST SEATTLE WA 98103 USA
# 927 N  78TH ST SEATTLE WA 98103 USA
# 315 N  80TH ST SEATTLE WA 98103 USA
# 349 N  81ST ST SEATTLE WA 98103 USA
# 555 N  79TH ST SEATTLE WA 98103 USA
# 347 N  79TH ST SEATTLE WA 98103 USA
# 556 N  80TH ST SEATTLE WA 98103 USA
# 340 N  77TH ST SEATTLE WA 98103 USA
# 7411 AURORA AVE N SEATTLE WA 98103 USA
# 519 N  85TH ST SEATTLE WA 98103 USA
# 938 N  84TH ST SEATTLE WA 98103 USA
# 556 N  82ND ST SEATTLE WA 98103 USA
# 353 N  84TH ST SEATTLE WA 98103 USA
# 927 N  85TH ST SEATTLE WA 98103 USA
# 8301 AURORA AVE N SEATTLE WA 98103 USA
# 725 N  82ND ST SEATTLE WA 98103 USA
# 930 N  83RD ST SEATTLE WA 98103 USA
# 8103 DAYTON AVE N SEATTLE WA 98103 USA
# 558 N  84TH ST SEATTLE WA 98103 USA
# 349 N  82ND ST SEATTLE WA 98103 USA
# 555 N  85TH ST SEATTLE WA 98103 USA
# 919 N  83RD ST SEATTLE WA 98103 USA
# 167 REPUBLICAN ST SEATTLE WA 98109 USA
# 635 ELLIOTT AVE W SEATTLE WA 98119 USA
# 500 5TH AVE W SEATTLE WA 98119 USA
# 101 ELLIOTT AVE W SEATTLE WA 98119 USA
# 135 1ST AVE W SEATTLE WA 98119 USA
# 533 3RD AVE W SEATTLE WA 98119 USA
# 524 6TH AVE W SEATTLE WA 98119 USA
# 530 4TH AVE W SEATTLE WA 98119 USA
# 323 W  REPUBLICAN ST SEATTLE WA 98119 USA
# 400 W  REPUBLICAN ST SEATTLE WA 98119 USA
# 500 W  REPUBLICAN ST SEATTLE WA 98119 USA
