# %%
import requests
import json

# %%
headers = {
    'authority': 'rl.quantummetric.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'content-type': 'application/json',
    'dnt': '1',
    'origin': 'https://www.xfinity.com',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?1',
    'sec-ch-ua-platform': '"Android"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'cross-site',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Mobile Safari/537.36',
}

json_data = [
    'Jxk0134xVbM=',
    'goUgPwBblbE=',
]

response = requests.post('https://rl.quantummetric.com/comcast/hash-check', headers=headers, json=json_data)

# %%
# import requests

# cookies = {
#      V nothing
#     'xpgn': '1', 

#      V nothing
#     'AKA_A2': 'A',

#      V nothing
#     '_abck': '2CBA306407EDA8C1EA6A796D65675617~-1~~-1~-1~-1',

#      V nothing
#     'bm_sz': '2B6F8BA0D90F4B4E816E727A701D5BB6~~4337720~4539462',

#      V nothing
#     'ak_bmsc': 'EEFA764FEF9B102D6F751AE6679798C6~000000000000000000000000000000~',

#      V THIS LINE CONTROLS VisitorId field, removing it makes the field change each time this request is run
#     'PSC': 'UCID=0efb09d3-38d8-4767-aff7-957a6402fa10',

#      V THIS LINE CONTROLS VisitorSessionId, removing it makes the field change each time this request is run
#     'SC': 'RC.USID=44af26fb-ac99-4006-bfab-804698bc3a4e&VA=1025',

#      V nothing
#     'www-prd_as': '2315478880.25088.0000',

#      V nothing
#     'TS014721c2': '01dab03c30307d3fa237f6ba5eb338fef097e7325afbcaca3179a3f39030c445163f0fbaa4a307924ceee931607ffcec633ba73c108b0c3e9faf53777366f5fc3433f18c48',

#      V nothing
#     'TS018621e0': '01dab03c30be1e6c6c1c3a884c574fdc6af5119177fbcaca3179a3f39030c445163f0fbaa45360a2a6eb75b06600386f05318606c925713439c10299734bd3208d72b4bc74630e0f25dbd8a56d2ba3669a0cc69ed7',
# }

# headers = {
#     'authority': 'www.xfinity.com',

#      This line is necessary
#     'accept': 'application/json, text/plain, */*',
#     'accept-language': 'en-US,en;q=0.9',
#     'adrum': 'isAjax:true',
#     # 'cookie': 'xpgn=1; AKA_A2=A; _abck=2CBA306407EDA8C1EA6A796D65675617~-1~~-1~-1~-1; bm_sz=2B6F8BA0D90F4B4E816E727A701D5BB6~~4337720~4539462; ak_bmsc=EEFA764FEF9B102D6F751AE6679798C6~000000000000000000000000000000~; PSC=UCID=0efb09d3-38d8-4767-aff7-957a6402fa10; SC=RC.USID=44af26fb-ac99-4006-bfab-804698bc3a4e&VA=1025; www-prd_as=2315478880.25088.0000; TS014721c2=01dab03c30307d3fa237f6ba5eb338fef097e7325afbcaca3179a3f39030c445163f0fbaa4a307924ceee931607ffcec633ba73c108b0c3e9faf53777366f5fc3433f18c48; TS018621e0=01dab03c30be1e6c6c1c3a884c574fdc6af5119177fbcaca3179a3f39030c445163f0fbaa45360a2a6eb75b06600386f05318606c925713439c10299734bd3208d72b4bc74630e0f25dbd8a56d2ba3669a0cc69ed7',
#     'dnt': '1',
#     'referer': 'https://www.xfinity.com/national/',
#     'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
#     'sec-ch-ua-mobile': '?1',
#     'sec-ch-ua-platform': '"Android"',
#     'sec-fetch-dest': 'empty',
#     'sec-fetch-mode': 'cors',
#     'sec-fetch-site': 'same-origin',

#      This line is necessary
#     'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Mobile Safari/537.36',
# }

# response = requests.get(
#     'https://www.xfinity.com/sitecore/api/learn/neptune/persistencelayer/usercontext',
#     cookies=cookies,
#     headers=headers,
# )

# %%
# Request that I believe will yield the id's needed for future requests
# AUTH

# no cookies needed
cookies = {}

# these 2 headers are necessary, as usual for most applications
headers = {
    'accept': 'application/json, text/plain, */*',
    'user-agent': 'Mozilla/5.0 (Linux; Android 6.0; Nexus 5 Build/MRA58N) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Mobile Safari/537.36'
}

# the target URL of usercontext seems to update as the session id gathers more data and will likely be used for verif later on
response = requests.get(
    'https://www.xfinity.com/sitecore/api/learn/neptune/persistencelayer/usercontext',
    cookies=cookies,
    headers=headers
)

# %%
t = response.json()
visitor_id = t['VisitorId']
v_session_id = t['VisitorSessionId']
visitor_id, v_session_id
# VisitorId":"0efb09d3-38d8-4767-aff7-957a6402fa10","VisitorSessionId":"44af26fb-ac99-4006-bfab-804698bc3a4e"
# Out:
# ('0ba9cb54-5c1a-403d-bb53-6f4eaa2fbecb',
#  'a18c52b7-11f8-49a4-ba94-b3bbc9802d26')

# %%
cookies = {
    'xpgn': '1',
    'AKA_A2': 'A',
    'Affiliate': 'DOT_COM',
    'Channel': 'WEB',
    'at_check': 'true',
    'AMCVS_DA11332E5321D0550A490D45%40AdobeOrg': '1',
    '__privaci_cookie_consent_uuid': '3ca9c751-4217-4ed9-8c8d-9dba2538ee3e:19',
    '__privaci_cookie_consent_generated': '3ca9c751-4217-4ed9-8c8d-9dba2538ee3e:19',
    '__privaci_cookie_consents': '{"consents":{"77":1,"78":1,"79":1,"80":1},"location":"WA#US","lang":"en","gpcInBrowserOnConsent":false,"gpcStatusInPortalOnConsent":false,"status":"record-consent-success","implicit_consent":true}',
    'kndctr_DA11332E5321D0550A490D45_AdobeOrg_identity': 'CiYzNjE5NDkwNTMxNTg0NjA2MjAwMDU3MTI5NjIyMjEzMzY0MjExMFIQCJug2uTMMRgBKgNPUjIwA_ABm6Da5Mwx',
    's_sess': '%20s_cc%3Dtrue%3B',
    'fltk': 'segID%3D2450016',
    '_gid': 'GA1.2.578150948.1704239472',
    '_gcl_au': '1.1.2002532799.1704239472',
    '_rdt_uuid': '1704239472463.a796d8ad-eeeb-4e75-8836-a3fd11af59df',
    '_fbp': 'fb.1.1704239472676.987082574',
    '_scid': '8dde9322-cacc-472d-b9c2-a1a5ed8fd1ae',
    'mdLogger': 'false',
    'kampyle_userid': 'cbd6-066a-a491-f78a-0199-d7fd-fae2-533c',
    'QuantumMetricSessionID': 'd168695e52656c2f0d7c687ccefc2d5f',
    'QuantumMetricUserID': 'c1a38d7fcf067196a7cbebe79cd8b7d8',
    '_pin_unauth': 'dWlkPU9HRTBPV1ExTm1ZdE9XVXhNeTAwWldJNExXSTJOMkl0WWpRNFlXVmtNak13TkRNeg',
    '_sctr': '1%7C1704182400000',
Fie0+jk0wcqhq1YoAMYBDAE4AXWCABm4gDYBnAKbUQEmQH0AjtICesFjSUB7AOaW1YHRAB2OtbTUPpO+REm25i1Ro04mBgPioqOgC25mDKOqIW6tBw-uqaEABGAB460moqsinKaTTaHrTKAK4aRQGaKpUZkRDSeXbmDiotNalqQhBqAO629u5qkg5qhQrFgXQDw3YADgAWHTUzdf1DI9LCtSXzO3bqopWSLcYHc-...-6jO2MggWmTxMsxrGSJxZQgVKkRLOs7j2MkcG8vyOiCrs5hcdM5EgOaerNG09zpvxLFwo4KkgXR2ljnhq6vI2NBgJYABi3gFAAMuYwS9v2fQ5nWACSAAicgkOIACK6AAOqSCQOC2dIgwAAo4AAUpEXkAFbwJYADyADCABqACiAAaXlgAAmvUzHSL5--DK6rDOi+gGtawwwu67A+s0PL6AsAqTCm495vq2Y1s63QesGwQWCIIgLBWjAoAqx751eyAmva59fv2wHPMsMg7v09Hl2W978e24nMAOyAHDwBQqDwOnwvm0QWCoAQOc23jsfiBnz2oDXdcKCozeV+d1e1xjCfiB9ecubAADaIt9wQAC6NAVgnpotyQRAh4gjbr0AA; _abck=1A595284EA30DF30EE73430A99265D10~-1~~-1~-1~-1; bm_sv=7CD63E580BEAB6BB67857BF6C1C6D31D~~1; s_pers=%20s_dslv%3D1704240953498%7C1798848953498%3B%20s_dfa%3Dcomcastdotcomprod%7C1704244582457%3B%20stc18%3D%7C1704244690149%3B%20s_tslv%3D1704242890150%7C1767314890150%3B%20gpv_Page%3Dresi%257Csales%257Cshop%257C%257Chome%7C1704244690152%3B; s_sq=comcastdotcomprod%3D%2526c.%2526a.%2526activitymap.%2526page%253Dresi%25257Csales%25257Cshop%25257C%25257Chome%2526link%253DCheck%252520availability%2526region%253Droot%2526pageIDType%253D1%2526.activitymap%2526.a%2526.c%2526pid%253Dresi%25257Csales%25257Cshop%25257C%25257Chome%2526pidt%253D1%2526oid%253DCheck%252520availability%2526oidt%253D3%2526ot%253DSUBMIT',
    'origin': 'https://www.xfinity.com',
    'referer': 'https://www.xfinity.com/national',
    'sec-ch-ua': '"Not_A Brand";v="8", "Chromium";v="120", "Google Chrome";v="120"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/120.0.0.0 Safari/537.36',
}

json_data = {
    'AutoBuild': False,
    'AdditionalQueryParams': '',
    'Address': {
        'ZipCode': '98122',
        'StreetAddress': '1717 E SPRUCE ST',
        'UnitType': None,
        'UnitNumber': None,
        'Unit': None,
        'LocationId': '291118302',
        'SingleStreetAddress': '1717 E SPRUCE ST, SEATTLE, WA 98122',
        'IsRequestFromSingleAddressField': True,
        'SearchReferenceId': None,
        'SalesSessionId': None,
        'Origins': 'csg,eloc',
        'IsMdu': False,
    },
    'RedirectURL': 'https://www.xfinity.com/digital/offers/plan-builder',
    'RedirectionType': '',
    'OfferId': '',
    'OfferLobs': '',
    'XeppPromoId': '',
    'TenantInfo': {},
    'isACPOpted': False,
    'DisableRedirectUrl': False,
}

response = requests.post(
    'https://www.xfinity.com/sitecore/api/learn/neptune/localize',
    cookies=cookies,
    headers=headers,
    json=json_data,
)
